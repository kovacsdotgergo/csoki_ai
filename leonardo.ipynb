# %%
import requests
import json

API_KEY = 'apa kulcs'
url = "https://cloud.leonardo.ai/api/rest/v1/generations"
payload = {
    "height": 512,
    "modelId": "6bef9f1b-29cb-40c7-b9df-32b51c1f67d3",
    "prompt": "An oil painting of a cat",
    "width": 512
}
headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "authorization": f"Bearer {API_KEY}"
}

response = requests.post(url, json=payload, headers=headers)
print(response.text)

generation_id = json.loads(response.text)['sdGenerationJob']['generationId']
# Out:
# {"sdGenerationJob":{"generationId":"1016aad4-baa0-4280-b9c4-e8f9c178ca84","apiCreditCost":null}}
# {"error":"Allowed methods: GET, DELETE","path":"$","code":"method-not-allowed"}

# %%
url = "https://cloud.leonardo.ai/api/rest/v1/generations/{}".format(generation_id)

headers = {
    "accept": "application/json",
    "authorization": f"Bearer {API_KEY}"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"generations_by_pk":{"generated_images":[{"url":"https://cdn.leonardo.ai/users/8f445d25-a67e-4bd5-b0cb-52ab58915306/generations/1016aad4-baa0-4280-b9c4-e8f9c178ca84/Leonardo_Creative_An_oil_painting_of_a_cat_0.jpg","nsfw":false,"id":"bbb3c7ae-ae3f-4063-abaa-685bfad42159","likeCount":0,"generated_image_variation_generics":[]}, {"url":"https://cdn.leonardo.ai/users/8f445d25-a67e-4bd5-b0cb-52ab58915306/generations/1016aad4-baa0-4280-b9c4-e8f9c178ca84/Leonardo_Creative_An_oil_painting_of_a_cat_1.jpg","nsfw":false,"id":"46d53607-787b-4ba1-9435-fc91687bc314","likeCount":0,"generated_image_variation_generics":[]}, {"url":"https://cdn.leonardo.ai/users/8f445d25-a67e-4bd5-b0cb-52ab58915306/generations/1016aad4-baa0-4280-b9c4-e8f9c178ca84/Leonardo_Creative_An_oil_painting_of_a_cat_2.jpg","nsfw":false,"id":"610272b1-5134-452c-884d-2a1a8eb8f3c3","likeCount":0,"generated_image_variation_generics":[]}, {"url":"https://cdn.leonardo.ai/users/8f445d25-a67e-4bd5-b0cb-52ab58915306/generations/1016aad4
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
images = json.loads(response.text)['generations_by_pk']['generated_images']
url = images[0]['url']
img_content = requests.get(url).content
with open('img.jpg', 'wb') as file:
    file.write(img_content)
